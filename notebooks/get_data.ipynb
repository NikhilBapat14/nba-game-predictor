# %%
# Code to get the data

# %%
import pandas as pd
import numpy as np

# %%
# Data Cleaning

# %%
df = pd.read_csv("/Users/abhaybapat/Desktop/Data Science Project/betting_classification_model/data/TeamStatistics.csv")

# %%
df.head()
# Out:
#      gameId      gameDateTimeEst       teamCity   teamName      teamId  \
# 0  42500302  2026-05-21 20:00:00      Cleveland  Cavaliers  1610612739
# 1  42500302  2026-05-21 20:00:00       New York     Knicks  1610612752
# 2  42500312  2026-05-20 20:30:00    San Antonio      Spurs  1610612759
# 3  42500312  2026-05-20 20:30:00  Oklahoma City    Thunder  1610612760
# 4  42500301  2026-05-19 20:00:00      Cleveland  Cavaliers  1610612739
#
#   opponentTeamCity opponentTeamName  opponentTeamId  home  win  ...  \
# 0         New York           Knicks      1610612752     0  0.0  ...
# 1        Cleveland        Cavaliers      1610612739     1  1.0  ...
# 2    Oklahoma City          Thunder      1610612760     0  0.0  ...
# 3      San Antonio            Spurs      1610612759     1  1.0  ...
# 4         New York           Knicks      1610612752     0  0.0  ...
#
#            gameLabel  gameSubLabel  seriesGameNumber  seed  reboundsTeam  \
# 0  East Conf. Finals        Game 2               2.0   4.0          11.0
# 1  East Conf. Finals        Game 2               2.0   3.0          14.0
# 2  West Conf. Finals        Game 2               2.0   2.0           4.0
# 3  West Conf. Finals        Game 2               2.0   1.0           9.0
# 4  East Conf. Finals        Game 1               1.0   4.0          17.0
#
#    turnoversTeam  ot1Points  ot2Points  otAllPoints             gameDate
# 0            0.0        NaN        NaN          NaN  2026-05-21 20:00:00
# 1            2.0        NaN        NaN          NaN  2026-05-21 20:00:00
# 2            0.0        NaN        NaN          NaN  2026-05-20 20:30:00
# 3            1.0        NaN        NaN          NaN  2026-05-20 20:30:00
# 4            2.0        3.0        NaN          3.0  2026-05-19 20:00:00
#
# [5 rows x 59 columns]

# %%
df.shape
# Out:
# (146536, 59)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 146536 entries, 0 to 146535
# Data columns (total 59 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   gameId                   146536 non-null  int64
#  1   gameDateTimeEst          146536 non-null  str
#  2   teamCity                 146520 non-null  str
#  3   teamName                 146534 non-null  str
#  4   teamId                   146536 non-null  int64
#  5   opponentTeamCity         146520 non-null  str
#  6   opponentTeamName         146534 non-null  str
#  7   opponentTeamId           146536 non-null  int64
#  8   home                     146536 non-null  int64
#  9   win                      146534 non-null  float64
#  10  teamScore                146536 non-null  int64
#  11  opponentScore            146536 non-null  int64
#  12  assists                  146532 non-null  float64
#  13  blocks                   146532 non-null  float64
#  14  steals                   146532 non-null  float64
#  15  fieldGoalsAttempted      146532 non-null  float64
#  16  fieldGoalsMade           146534 non-null  float64
#  17  fieldGoalsPercentage     146532 non-null  float64
#  18  threePointersAttempted   146532 non-null  float64
#  19  threePointersMade        146532 non-null  float64
#  20  threePointersPercentage  146531 non-null  float64
#  21  freeThrowsAttempted      146532 non-null  float64
#  22  freeThrowsMade           146534 non-null  float64
#  23  freeThrowsPercentage     146532 non-null  float64
#  24  reboundsDefensive        146532 non-null  float64
#  25  reboundsOffensive        146532 non-null  float64
#  26  reboundsTotal            146532 non-null  float64
#  27  foulsPersonal            146532 non-null  float64
#  28  turnovers                146532 non-null  float64
#  29  plusMinusPoints          146479 non-null  float64
#  30  numMinutes               146530 non-null  float64
#  31  q1Points                 138688 non-null  float64
#  32  q2Points                 138672 non-null  float64
#  33  q3Points                 138638 non-null  float64
#  34  q4Points                 138636 non-null  float64
#  35  benchPoints              139226 non-null  float64
#  36  biggestLead              139226 non-null  float64
#  37  biggestScoringRun        139226 non-null  float64
#  38  leadChanges              139226 non-null  float64
#  39  pointsFastBreak          139226 non-null  float64
#  40  pointsFromTurnovers      139226 non-null  float64
#  41  pointsInThePaint         139226 non-null  float64
#  42  pointsSecondChance       139226 non-null  float64
#  43  timesTied                139226 non-null  float64
#  44  timeoutsRemaining        139226 non-null  float64
#  45  seasonWins               139226 non-null  float64
#  46  seasonLosses             139226 non-null  float64
#  47  coachId                  0 non-null       float64
#  48  gameType                 138946 non-null  str
#  49  gameLabel                9286 non-null    str
#  50  gameSubLabel             9204 non-null    str
#  51  seriesGameNumber         8854 non-null    float64
#  52  seed                     7848 non-null    float64
#  53  reboundsTeam             138946 non-null  float64
#  54  turnoversTeam            138946 non-null  float64
#  55  ot1Points                7816 non-null    float64
#  56  ot2Points                1106 non-null    float64
#  57  otAllPoints              7820 non-null    float64
#  58  gameDate                 146536 non-null  str
# dtypes: float64(44), int64(6), str(9)
# memory usage: 66.0 MB

# %%
df["gameDateTimeEst"] = pd.to_datetime(df["gameDateTimeEst"])

# %%
df["gameDateTimeEst"].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 146536 entries, 0 to 146535
# Series name: gameDateTimeEst
# Non-Null Count   Dtype
# --------------   -----
# 146536 non-null  datetime64[us]
# dtypes: datetime64[us](1)
# memory usage: 1.1 MB

# %%
df = df.loc[df["gameDateTimeEst"] >= "1986-10-30 20:00:00"]

# %%
df.shape
# Out:
# (102704, 59)

# %%
df.sort_values(by="gameDateTimeEst")
# Out:
#           gameId     gameDateTimeEst       teamCity       teamName  \
# 102703  28600009 1986-10-31 20:00:00   Golden State       Warriors
# 102686  28600001 1986-10-31 20:00:00       Portland  Trail Blazers
# 102687  28600001 1986-10-31 20:00:00        Seattle    SuperSonics
# 102688  28600002 1986-10-31 20:00:00   Philadelphia          76ers
# 102689  28600002 1986-10-31 20:00:00        Indiana         Pacers
# ...          ...                 ...            ...            ...
# 4       42500301 2026-05-19 20:00:00      Cleveland      Cavaliers
# 3       42500312 2026-05-20 20:30:00  Oklahoma City        Thunder
# 2       42500312 2026-05-20 20:30:00    San Antonio          Spurs
# 1       42500302 2026-05-21 20:00:00       New York         Knicks
# 0       42500302 2026-05-21 20:00:00      Cleveland      Cavaliers
#
#             teamId opponentTeamCity opponentTeamName  opponentTeamId  home  \
# 102703  1610612744          Phoenix             Suns      1610612756     0
# 102686  1610612757          Seattle      SuperSonics      1610612760     1
# 102687  1610612760         Portland    Trail Blazers      1610612757     0
# 102688  1610612755          Indiana           Pacers      1610612754     1
# 102689  1610612754     Philadelphia            76ers      1610612755     0
# ...            ...              ...              ...             ...   ...
# 4       1610612739         New York           Knicks      1610612752     0
# 3       1610612760      San Antonio            Spurs      1610612759     1
# 2       1610612759    Oklahoma City          Thunder      1610612760     0
# 1       1610612752        Cleveland        Cavaliers      1610612739     1
# 0       1610612739         New York           Knicks      1610612752     0
#
#         win  ...          gameLabel  gameSubLabel  seriesGameNumber  seed  \
# 102703  0.0  ...                NaN           NaN               NaN   NaN
# 102686  0.0  ...                NaN           NaN               NaN   NaN
# 102687  1.0  ...                NaN           NaN               NaN   NaN
# 102688  1.0  ...                NaN           NaN               NaN   NaN
# 102689  0.0  ...                NaN           NaN               NaN   NaN
# ...     ...  ...                ...           ...               ...   ...
# 4       0.0  ...  East Conf. Finals        Game 1               1.0   4.0
# 3       1.0  ...  West Conf. Finals        Game 2               2.0   1.0
# 2       0.0  ...  West Conf. Finals        Game 2               2.0   2.0
# 1       1.0  ...  East Conf. Finals        Game 2               2.0   3.0
# 0       0.0  ...  East Conf. Finals        Game 2               2.0   4.0
#
#         reboundsTeam  turnoversTeam  ot1Points  ot2Points  otAllPoints  \
# 102703           0.0            0.0        NaN        NaN          NaN
# 102686           0.0            0.0        NaN        NaN          NaN
# 102687           0.0            0.0        NaN        NaN          NaN
# 102688           0.0            0.0        NaN        NaN          NaN
# 102689           0.0            0.0        NaN        NaN          NaN
# ...              ...            ...        ...        ...          ...
# 4               17.0            2.0        3.0        NaN          3.0
# 3                9.0            1.0        NaN        NaN          NaN
# 2                4.0            0.0        NaN        NaN          NaN
# 1               14.0            2.0        NaN        NaN          NaN
# 0               11.0            0.0        NaN        NaN          NaN
#
#                    gameDate
# 102703  1986-10-31 20:00:00
# 102686  1986-10-31 20:00:00
# 102687  1986-10-31 20:00:00
# 102688  1986-10-31 20:00:00
# 102689  1986-10-31 20:00:00
# ...                     ...
# 4       2026-05-19 20:00:00
# 3       2026-05-20 20:30:00
# 2       2026-05-20 20:30:00
# 1       2026-05-21 20:00:00
# 0       2026-05-21 20:00:00
#
# [102704 rows x 59 columns]

# %%
hornets_teams = df[df["teamName"] == "Hornets"]
hornets_teams["teamCity"].value_counts()
# Out:
# teamCity
# Charlotte        2195
# New Orleans       802
# Oklahoma City     178
# Name: count, dtype: int64

# %%
conditions = [
    (df['teamCity'] == 'Seattle') & (df['teamName'] == 'SuperSonics'),
    (df['teamCity'] == 'Washington') & (df['teamName'] == 'Bullets'),
    (df['teamCity'] == 'New Orleans') & (df['teamName'] == 'Hornets'),
    (df['teamCity'] == 'Oklahoma City') & (df['teamName'] == 'Hornets'),
    (df['teamCity'] == 'Charlotte') & (df['teamName'] == 'Bobcats'),
]

new_cities = ['Oklahoma City', 'Washington', 'New Orleans', 'New Orleans', 'Charlotte']
new_names = ['Thunder', 'Wizards', 'Pelicans', 'Pelicans', 'Hornets']

df['teamName'] = np.select(conditions, new_names, default=df['teamName'])

# %%
df = df.loc[:, "gameId":"turnovers"]

# %%
columns_to_drop = ["teamCity", "opponentTeamCity", "opponentTeamId", "opponentTeamName", "opponentScore"]
df = df.drop(columns=columns_to_drop)

# %%
df.shape
# Out:
# (102704, 24)

# %%
df.isna().sum()
# Out:
# gameId                     0
# gameDateTimeEst            0
# teamName                   2
# teamId                     0
# home                       0
# win                        2
# teamScore                  0
# assists                    2
# blocks                     2
# steals                     2
# fieldGoalsAttempted        2
# fieldGoalsMade             2
# fieldGoalsPercentage       2
# threePointersAttempted     2
# threePointersMade          2
# threePointersPercentage    3
# freeThrowsAttempted        2
# freeThrowsMade             2
# freeThrowsPercentage       2
# reboundsDefensive          2
# reboundsOffensive          2
# reboundsTotal              2
# foulsPersonal              2
# turnovers                  2
# dtype: int64

# %%
missing_rows = df[df.isna().any(axis=1)]
remove_games = missing_rows["gameId"].unique()
df = df.loc[~df["gameId"].isin(remove_games)]

# %%
df.isna().sum()
# Out:
# gameId                     0
# gameDateTimeEst            0
# teamName                   0
# teamId                     0
# home                       0
# win                        0
# teamScore                  0
# assists                    0
# blocks                     0
# steals                     0
# fieldGoalsAttempted        0
# fieldGoalsMade             0
# fieldGoalsPercentage       0
# threePointersAttempted     0
# threePointersMade          0
# threePointersPercentage    0
# freeThrowsAttempted        0
# freeThrowsMade             0
# freeThrowsPercentage       0
# reboundsDefensive          0
# reboundsOffensive          0
# reboundsTotal              0
# foulsPersonal              0
# turnovers                  0
# dtype: int64

# %%
df.teamName.value_counts()
# Out:
# teamName
# Lakers            3752
# Celtics           3710
# Spurs             3686
# Bulls             3622
# Thunder           3619
# Pacers            3619
# Pistons           3606
# Jazz              3603
# Rockets           3586
# Suns              3575
# Cavaliers         3573
# Mavericks         3570
# Knicks            3564
# Trail Blazers     3559
# Warriors          3550
# Hawks             3545
# Nuggets           3542
# 76ers             3531
# Bucks             3519
# Heat              3489
# Nets              3474
# Clippers          3473
# Kings             3422
# Wizards           3419
# Magic             3248
# Timberwolves      3191
# Hornets           3074
# Raptors           2727
# Grizzlies         2708
# Pelicans          2120
# Stripes              3
# Stars                3
# Loong-Lions          3
# World                2
# Team Vince           2
# Team Melo            2
# Team T-Mac           1
# Team Austin          1
# Phoenix              1
# Jerusalem B.C.       1
# United               1
# Name: count, dtype: int64

# %%
count_teams = df.groupby("teamName")["teamName"].transform("count")
df = df[count_teams > 3]

# %%
df.teamName.value_counts()
# Out:
# teamName
# Lakers           3752
# Celtics          3710
# Spurs            3686
# Bulls            3622
# Thunder          3619
# Pacers           3619
# Pistons          3606
# Jazz             3603
# Rockets          3586
# Suns             3575
# Cavaliers        3573
# Mavericks        3570
# Knicks           3564
# Trail Blazers    3559
# Warriors         3550
# Hawks            3545
# Nuggets          3542
# 76ers            3531
# Bucks            3519
# Heat             3489
# Nets             3474
# Clippers         3473
# Kings            3422
# Wizards          3419
# Magic            3248
# Timberwolves     3191
# Hornets          3074
# Raptors          2727
# Grizzlies        2708
# Pelicans         2120
# Name: count, dtype: int64

# %%
df = df.rename(columns={"teamScore": "points"})

# %%
df
# Out:
#           gameId     gameDateTimeEst   teamName      teamId  home  win  \
# 0       42500302 2026-05-21 20:00:00  Cavaliers  1610612739     0  0.0
# 1       42500302 2026-05-21 20:00:00     Knicks  1610612752     1  1.0
# 2       42500312 2026-05-20 20:30:00      Spurs  1610612759     0  0.0
# 3       42500312 2026-05-20 20:30:00    Thunder  1610612760     1  1.0
# 4       42500301 2026-05-19 20:00:00  Cavaliers  1610612739     0  0.0
# ...          ...                 ...        ...         ...   ...  ...
# 102699  28600007 1986-10-31 20:00:00      Spurs  1610612759     0  0.0
# 102700  28600008 1986-10-31 20:00:00       Jazz  1610612762     0  0.0
# 102701  28600008 1986-10-31 20:00:00  Mavericks  1610612742     1  1.0
# 102702  28600009 1986-10-31 20:00:00       Suns  1610612756     1  1.0
# 102703  28600009 1986-10-31 20:00:00   Warriors  1610612744     0  0.0
#
#         points  assists  blocks  steals  ...  threePointersMade  \
# 0           93     15.0     5.0     4.0  ...                9.0
# 1          109     32.0     5.0     5.0  ...               13.0
# 2          113     22.0     6.0     5.0  ...               16.0
# 3          122     34.0     3.0    14.0  ...               13.0
# 4          104     23.0     6.0    11.0  ...               16.0
# ...        ...      ...     ...     ...  ...                ...
# 102699     104     27.0     4.0     7.0  ...                2.0
# 102700      77     21.0     2.0     5.0  ...                0.0
# 102701     103     14.0     5.0     7.0  ...                2.0
# 102702     127     29.0    10.0     9.0  ...                0.0
# 102703     123     26.0     3.0    15.0  ...                1.0
#
#         threePointersPercentage  freeThrowsAttempted  freeThrowsMade  \
# 0                         0.257                 32.0            22.0
# 1                         0.361                 14.0             8.0
# 2                         0.400                 17.0            15.0
# 3                         0.361                 24.0            19.0
# 4                         0.320                 23.0            16.0
# ...                         ...                  ...             ...
# 102699                    0.333                 24.0            16.0
# 102700                    0.000                 30.0            21.0
# 102701                    0.667                 47.0            37.0
# 102702                    0.000                 36.0            29.0
# 102703                    0.167                 31.0            24.0
#
#         freeThrowsPercentage  reboundsDefensive  reboundsOffensive  \
# 0                      0.688               29.0               13.0
# 1                      0.571               35.0                5.0
# 2                      0.882               29.0               16.0
# 3                      0.792               24.0               17.0
# 4                      0.696               27.0               11.0
# ...                      ...                ...                ...
# 102699                 0.667               18.0               16.0
# 102700                 0.700               29.0               15.0
# 102701                 0.787               44.0               16.0
# 102702                 0.806               36.0               14.0
# 102703                 0.774               27.0               18.0
#
#         reboundsTotal  foulsPersonal  turnovers
# 0                42.0           20.0        8.0
# 1                40.0           22.0        6.0
# 2                45.0           21.0       21.0
# 3                41.0           21.0        9.0
# 4                38.0           29.0       19.0
# ...               ...            ...        ...
# 102699           34.0           22.0       17.0
# 102700           44.0           33.0       21.0
# 102701           60.0           31.0       22.0
# 102702           50.0           19.0       23.0
# 102703           45.0           31.0       18.0
#
# [102676 rows x 24 columns]

# %%
# Calculate single game features

# %%
def shift_opponent_stats(df):
    df = df.sort_values(by=["gameDateTimeEst", "gameId", "home"])

    opp_map = df[["gameId", "home", "reboundsDefensive", "points"]].copy()
    
    opp_map["home"] = opp_map["home"].replace({1: 0, 0: 1})
    
    opp_map = opp_map.rename(columns={
        "reboundsDefensive": "opp_dreb",
        "points": "opponentScore"
    })
    
    df = pd.merge(df, opp_map, on=["gameId", "home"], how="left")

    return df

# %%
def create_four_factors(df):

    df["possessions"] = .96 * (df["fieldGoalsAttempted"] + df["turnovers"] + .44 * df["freeThrowsAttempted"] - df["reboundsOffensive"])

    df["eFG"] = (df["fieldGoalsMade"] + .5 * df["threePointersMade"]) / df["fieldGoalsAttempted"]

    df["TO%"] = df["turnovers"] / df["possessions"]

    df["OREB%"] = (df["reboundsOffensive"]) / (df["reboundsOffensive"] + df["opp_dreb"])

    df["FTR"] = df["freeThrowsAttempted"] / df["fieldGoalsAttempted"]

    df = df.drop(columns=df.loc[:,"assists":"opp_dreb"].columns)

    return df

# %%
def team_rating(df):
    df["off_rating"] = (df["points"] / df["possessions"]) * 100
    df["def_rating"] = (df["opponentScore"] / df["possessions"]) * 100
    df["net_rating"] = df["off_rating"] - df["def_rating"]

    df = df.drop(columns="opponentScore")

    return df

# %%
df = shift_opponent_stats(df)
df = create_four_factors(df)
df = team_rating(df)

# %%
df
# Out:
#           gameId     gameDateTimeEst       teamName      teamId  home  win  \
# 0       28600001 1986-10-31 20:00:00        Thunder  1610612760     0  1.0
# 1       28600001 1986-10-31 20:00:00  Trail Blazers  1610612757     1  0.0
# 2       28600002 1986-10-31 20:00:00         Pacers  1610612754     0  0.0
# 3       28600002 1986-10-31 20:00:00          76ers  1610612755     1  1.0
# 4       28600003 1986-10-31 20:00:00        Wizards  1610612764     0  0.0
# ...          ...                 ...            ...         ...   ...  ...
# 102671  42500301 2026-05-19 20:00:00         Knicks  1610612752     1  1.0
# 102672  42500312 2026-05-20 20:30:00          Spurs  1610612759     0  0.0
# 102673  42500312 2026-05-20 20:30:00        Thunder  1610612760     1  1.0
# 102674  42500302 2026-05-21 20:00:00      Cavaliers  1610612739     0  0.0
# 102675  42500302 2026-05-21 20:00:00         Knicks  1610612752     1  1.0
#
#         points  possessions       eFG       TO%     OREB%       FTR  \
# 0          127     102.2976  0.622093  0.224834  0.448276  0.279070
# 1          110     100.1088  0.506494  0.199783  0.272727  0.480519
# 2          104      94.4640  0.469880  0.148205  0.318182  0.421687
# 3          108     100.0320  0.523810  0.249920  0.461538  0.357143
# 4          102      98.7264  0.435294  0.222838  0.400000  0.423529
# ...        ...          ...       ...       ...       ...       ...
# 102671     115     105.6768  0.534091  0.160868  0.250000  0.363636
# 102672     113      92.6208  0.583333  0.226731  0.400000  0.202381
# 102673     122      92.6976  0.547872  0.097090  0.369565  0.255319
# 102674      93      85.5168  0.443750  0.093549  0.270833  0.400000
# 102675     109      88.4736  0.594118  0.067817  0.147059  0.164706
#
#         off_rating  def_rating  net_rating
# 0       124.147585  107.529404   16.618181
# 1       109.880450  126.861974  -16.981524
# 2       110.094851  114.329268   -4.234417
# 3       107.965451  103.966731    3.998720
# 4       103.315830  121.548036  -18.232205
# ...            ...         ...         ...
# 102671  108.822372   98.413275   10.409096
# 102672  122.002833  131.719873   -9.717040
# 102673  131.610743  121.901754    9.708989
# 102674  108.750561  127.460335  -18.709774
# 102675  123.200593  105.116102   18.084491
#
# [102676 rows x 15 columns]
